# %%
# you will be prompted with a window asking to grant permissions
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# fill in the path in your Google Drive in the string below. Note: do not escape slashes or spaces
import os
datadir = "/content/drive/MyDrive/CS444/assignment4"
if not os.path.exists(datadir):
  # !ln -s "/content/drive/MyDrive/CS444/assignment4" $datadir # TODO: Fill your Assignment 4 path
os.chdir(datadir)
# !pwd
# Out:
# /content/drive/MyDrive/CS444/assignment4

# %%
# NOTE: Loading data from Google Drive is VERY SLOW. Therefore, we download the data to a local storage
# specified by VOC_PATH.
# This means the data would have be re-downloaded everytime.
# Change this path if you are running this script locally
VOC_PATH="/content/VOC_DATA"

# %%
# !chmod u+x ./download_data.sh
# !sed -i 's/\r//g' ./download_data.sh
# !cat ./download_data.sh
# !bash ./download_data.sh $VOC_PATH
# Out:
# #!/usr/bin/env bash
#
# if [ "$#" -ne 1 ]; then
#     echo "Usage: $0 <data_path>"
#     exit 1
# fi
#
# DATA_DIR="$1"
#
# mkdir -p "$DATA_DIR"
#
# cd "$DATA_DIR" || { echo "Could not change directory to '$DATA_DIR'"; exit 1; }
# # cd data
#
# # download train
# wget http://host.robots.ox.ac.uk/pascal/VOC/voc2007/VOCtrainval_06-Nov-2007.tar
# tar -xf VOCtrainval_06-Nov-2007.tar
# mv VOCdevkit VOCdevkit_2007
# rm VOCtrainval_06-Nov-2007.tar
#
# # download test and combine into same directory
# wget http://host.robots.ox.ac.uk/pascal/VOC/voc2007/VOCtest_06-Nov-2007.tar
# tar -xf VOCtest_06-Nov-2007.tar
# mv VOCdevkit/VOC2007 VOCdevkit_2007/VOC2007test
# rmdir VOCdevkit
# rm VOCtest_06-Nov-2007.tar
#
# # MIRROR Links (comment out above and uncomment out below if host.robots.ox.au.uk is down)
#
# # wget http://pjreddie.com/media/files/VOCtrainval_06-Nov-2007.tar
# # tar -xf VOCtrainval_06-Nov-2007.tar
# # mv VOCdevkit VOCdevkit_2007
#
# # wget http://pjreddie.com/media/files/VOCtest_06-Nov-2007.tar
# # tar -xf VOCtest_06-Nov-2007.tar
# # mv VOCdevkit/VOC2007 VOCdevkit_2007/VOC2007test
# # rmdir VOCdevkit
#
# --2025-04-19 12:43:57--  http://host.robots.ox.ac.uk/pascal/VOC/voc2007/VOCtrainval_06-Nov-2007.tar
# Resolving host.robots.ox.ac.uk (host.robots.ox.ac.uk)... 129.67.94.152
# Connecting to host.robots.ox.ac.uk (host.robots.ox.ac.uk)|129.67.94.152|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 460032000 (439M) [application/x-tar]
# Saving to: ‘VOCtrainval_06-Nov-2007.tar’
#
# VOCtrainval_06-Nov- 100%[===================>] 438.72M  18.2MB/s    in 44s
#
# 2025-04-19 12:44:41 (10.0 MB/s) - ‘VOCtrainval_06-Nov-2007.tar’ saved [460032000/460032000]
#
# --2025-04-19 12:44:42--  http://host.robots.ox.ac.uk/pascal/VOC/voc2007/VOCtest_06-Nov-2007.tar
# Resolving host.robots.ox.ac.uk (host.robots.ox.ac.uk)... 129.67.94.152
# Connecting to host.robots.ox.ac.uk (host.robots.ox.ac.uk)|129.67.94.152|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 451020800 (430M) [application/x-tar]
# Saving to: ‘VOCtest_06-Nov-2007.tar’
#
# VOCtest_06-Nov-2007 100%[===================>] 430.13M  21.0MB/s    in 28s
#
# 2025-04-19 12:45:11 (15.3 MB/s) - ‘VOCtest_06-Nov-2007.tar’ saved [451020800/451020800]

# %%
import os
import random

import cv2
import numpy as np

import torch
from torch.utils.data import DataLoader

from src.resnet_yolo import resnet50
import yolo_loss
from src.dataset import VocDetectorDataset
from src.eval_voc import evaluate
from src.predict import predict_image
from src.config import VOC_CLASSES, COLORS
from kaggle_submission import output_submission_csv

import matplotlib.pyplot as plt
import collections

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Initialization

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda:0

# %%
# YOLO network hyperparameters
B = 2  # number of bounding box predictions per cell
S = 14  # width/height of network output grid (larger than 7x7 from paper since we use a different network)

# %%
# We recommend tuning only the batch size; the remaining hyperparameters should work well
# with the default values. However, you are free to experiment with them.

learning_rate = 1.5e-3
num_epochs = 50
batch_size = 18

# Yolo loss component coefficients (as given in Yolo v1 paper)
lambda_coord = 5
lambda_noobj = 0.5

# %% [markdown]
# ## Reading Pascal Data

# %% [markdown]
# Since Pascal is a small dataset (5000 in train+val) we have combined the train and val splits to train our detector. This is not typically a good practice, but we will make an exception in this case to be able to get reasonable detection results with a comparatively small object detection dataset.
#
# The train dataset loader also using a variety of data augmentation techniques including random shift, scaling, crop, and flips. Data augmentation is slightly more complicated for detection datasets since the bounding box annotations must be kept consistent throughout the transformations.
#
# Since the output of the detector network we train is an SxSx(B*5+C), we use an encoder to convert the original bounding box coordinates into relative grid bounding box coordinates corresponding to the expected output. We also use a decoder which allows us to convert the opposite direction into image coordinate bounding boxes.

# %%
file_root_train = os.path.join(VOC_PATH, 'VOCdevkit_2007/VOC2007/JPEGImages/')
annotation_file_train = 'data/voc2007.txt'

train_dataset = VocDetectorDataset(root_img_dir=file_root_train,dataset_file=annotation_file_train,train=True, S=S)
train_loader = DataLoader(train_dataset,batch_size=batch_size,shuffle=True,num_workers=2)
print('Loaded %d train images' % len(train_dataset))
# Out:
# Initializing dataset
# Loaded 5011 train images

# %%
file_root_test = os.path.join(VOC_PATH, 'VOCdevkit_2007/VOC2007test/JPEGImages/')
annotation_file_test = 'data/voc2007test.txt'

test_dataset = VocDetectorDataset(root_img_dir=file_root_test,dataset_file=annotation_file_test,train=False, S=S)
test_loader = DataLoader(test_dataset,batch_size=batch_size,shuffle=False,num_workers=2)
print('Loaded %d test images' % len(test_dataset))
# Out:
# Initializing dataset
# Loaded 4950 test images

# %%
data = train_dataset[0]
#print(data)

# %% [markdown]
# ## Initializing the network
#
# ## **Start from here if you modified yolo_loss.py and wish to retrain**

# %% [markdown]
# To implement Yolo we will rely on a pretrained classifier as the backbone for our detection network. PyTorch offers a variety of models which are pretrained on ImageNet in the [`torchvision.models`](https://pytorch.org/docs/stable/torchvision/models.html) package. In particular, we will use the ResNet50 architecture as a base for our detector. This is different from the base architecture in the Yolo paper and also results in a different output grid size (14x14 instead of 7x7).
#
# Models are typically pretrained on ImageNet since the dataset is very large (> 1 million images) and widely used. The pretrained model provides a very useful weight initialization for our detector, so that the network is able to learn quickly and effectively.

# %%
load_network_path = None
pretrained = True

# use to load a previously trained network
if load_network_path is not None:
    print('Loading saved network from {}'.format(load_network_path))
    net = resnet50().to(device)
    net.load_state_dict(torch.load(load_network_path))
else:
    print('Load pre-trained model')
    net = resnet50(pretrained=pretrained).to(device)
# Out:
# Load pre-trained model

# %%
# Print the model
print(net)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer5): Sequential(
#     (0): DetnetBottleneck(
#       (conv1): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): DetnetBottleneck(
#       (conv1): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential()
#     )
#     (2): DetnetBottleneck(
#       (conv1): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential()
#     )
#   )
#   (conv_end): Conv2d(256, 30, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn_end): BatchNorm2d(30, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# )

# %% [markdown]
# ## Set up training tools

# %%
from importlib import reload
reload(yolo_loss) # update the import if the implementation has changed

criterion = yolo_loss.YoloLoss(S, B, lambda_coord, lambda_noobj)
optimizer = torch.optim.SGD(net.parameters(), lr=learning_rate, momentum=0.9, weight_decay=5e-4)
# optimizer = torch.optim.AdamW(net.parameters(), lr=learning_rate, betas=(0.9, 0.999), weight_decay=1e-3)

# %% [markdown]
# ## Train detector

# %%
best_test_loss = np.inf
learning_rate = learning_rate

os.makedirs('./checkpoints', exist_ok=True)
for epoch in range(num_epochs):
    net.train()

    # Update learning rate late in training
    if epoch == 30 or epoch == 40:
        learning_rate /= 10.0

    for param_group in optimizer.param_groups:
        param_group['lr'] = learning_rate

    print('\n\nStarting epoch %d / %d' % (epoch + 1, num_epochs))
    print('Learning Rate for this epoch: {}'.format(learning_rate))

    total_loss = collections.defaultdict(int)

    for i, data in enumerate(train_loader):
        data = (item.to(device) for item in data)
        images, target_boxes, target_cls, has_object_map = data
        pred = net(images)
        loss_dict = criterion(pred, target_boxes, target_cls, has_object_map)
        for key in loss_dict:
            total_loss[key] += loss_dict[key].item()

        optimizer.zero_grad()
        loss_dict['total_loss'].backward()
        optimizer.step()

        if (i+1) % 50 == 0:
            outstring = 'Epoch [%d/%d], Iter [%d/%d], Loss: ' % ((epoch+1, num_epochs, i+1, len(train_loader)))
            outstring += ', '.join( "%s=%.3f" % (key[:-5], val / (i+1)) for key, val in total_loss.items() )
            print(outstring)

    # evaluate the network on the test data
    if (epoch + 1) % 5 == 0:
        test_aps = evaluate(net, test_dataset_file=annotation_file_test, img_root=file_root_test)
        print(epoch, test_aps)
    with torch.no_grad():
        test_loss = 0.0
        net.eval()
        for i, data in enumerate(test_loader):
            data = (item.to(device) for item in data)
            images, target_boxes, target_cls, has_object_map = data

            pred = net(images)
            loss_dict = criterion(pred, target_boxes, target_cls, has_object_map)
            test_loss += loss_dict['total_loss'].item()
        test_loss /= len(test_loader)

    if best_test_loss > test_loss:
        best_test_loss = test_loss
        print('Updating best test loss: %.5f' % best_test_loss)
        torch.save(net.state_dict(),'checkpoints/best_detector.pth')

    if (epoch+1) in [5, 10, 20, 30, 40]:
        torch.save(net.state_dict(),'checkpoints/detector_epoch_%d.pth' % (epoch+1))

    torch.save(net.state_dict(),'checkpoints/detector.pth')
# Out:
# Starting epoch 1 / 50
# Learning Rate for this epoch: 0.0015
# Epoch [1/50], Iter [50/279], Loss: total=21.657, reg=4.018, containing_obj=0.327, no_obj=9.763, cls=7.550
# Epoch [1/50], Iter [100/279], Loss: total=14.711, reg=3.432, containing_obj=0.410, no_obj=4.989, cls=5.879
# Epoch [1/50], Iter [150/279], Loss: total=12.142, reg=3.182, containing_obj=0.471, no_obj=3.380, cls=5.110
# Epoch [1/50], Iter [200/279], Loss: total=10.678, reg=2.995, containing_obj=0.511, no_obj=2.567, cls=4.605
# Epoch [1/50], Iter [250/279], Loss: total=9.686, reg=2.858, containing_obj=0.540, no_obj=2.076, cls=4.212
# Updating best test loss: 5.30308
#
#
# Starting epoch 2 / 50
# Learning Rate for this epoch: 0.0015
# Epoch [2/50], Iter [50/279], Loss: total=5.350, reg=2.243, containing_obj=0.716, no_obj=0.093, cls=2.298
# Epoch [2/50], Iter [100/279], Loss: total=5.170, reg=2.201, containing_obj=0.707, no_obj=0.089, cls=2.173
# Epoch [2/50], Iter [150/279], Loss: total=5.053, reg=2.154, containing_obj=0.706, no_obj=0.086, cls=2.107
# Epoch [2/50], Iter [200/279], Loss: total=5.007, reg=2.147, containing_obj=0.716, no_obj=0.083, cls=2.061
# Epoch [2/50], Iter [250/279], Loss: total=4.947, reg=2.127, containing_obj=0.719, no_obj=0.081, cls=2.020
# Updating best test loss: 4.66937
#
#
# Starting epoch 3 / 50
# Learning Rate for this epoch: 0.0015
# Epoch [3/50], Iter [50/279], Loss: total=4.536, reg=2.026, containing_obj=0.738, no_obj=0.067, cls=1.705
# Epoch [3/50], Iter [100/279], Loss: total=4.494, reg=1.976, containing_obj=0.743, no_obj=0.067, cls=1.708
# Epoch [3/50], Iter [150/279], Loss: total=4.514, reg=1.997, containing_obj=0.751, no_obj=0.066, cls=1.700
# Epoch [3/50], Iter [200/279], Loss: total=4.482, reg=1.985, containing_obj=0.760, no_obj=0.066, cls=1.671
# Epoch [3/50], Iter [250/279], Loss: total=4.490, reg=1.993, containing_obj=0.765, no_obj=0.066, cls=1.666
# Updating best test loss: 4.43624
#
#
# Starting epoch 4 / 50
# Learning Rate for this epoch: 0.0015
# Epoch [4/50], Iter [50/279], Loss: total=4.255, reg=1.920, containing_obj=0.762, no_obj=0.071, cls=1.501
# Epoch [4/50], Iter [100/279], Loss: total=4.238, reg=1.933, containing_obj=0.763, no_obj=0.072, cls=1.470
# Epoch [4/50], Iter [150/279], Loss: total=4.209, reg=1.904, containing_obj=0.766, no_obj=0.073, cls=1.467
# Epoch [4/50], Iter [200/279], Loss: total=4.203, reg=1.897, containing_obj=0.769, no_obj=0.074, cls=1.463
# Epoch [4/50], Iter [250/279], Loss: total=4.208, reg=1.899, containing_obj=0.771, no_obj=0.075, cls=1.464
# Updating best test loss: 4.21685
#
#
# Starting epoch 5 / 50
# Learning Rate for this epoch: 0.0015
# Epoch [5/50], Iter [50/279], Loss: total=3.894, reg=1.775, containing_obj=0.750, no_obj=0.086, cls=1.283
# Epoch [5/50], Iter [100/279], Loss: total=4.048, reg=1.862, containing_obj=0.774, no_obj=0.087, cls=1.324
# Epoch [5/50], Iter [150/279], Loss: total=3.994, reg=1.829, containing_obj=0.773, no_obj=0.089, cls=1.304
# Epoch [5/50], Iter [200/279], Loss: total=3.978, reg=1.825, containing_obj=0.773, no_obj=0.089, cls=1.291
# Epoch [5/50], Iter [250/279], Loss: total=3.960, reg=1.818, containing_obj=0.769, no_obj=0.090, cls=1.283
# ---Evaluate model on test samples---
# 100%|██████████| 4950/4950 [01:42<00:00, 48.25it/s]
# ---class aeroplane ap 0.017543859649122806---
# ---class bicycle ap 0.10852847961393561---
# ---class bird ap 0.08220051889876803---
# ---class boat ap 0.0--- (no predictions for this class)
# ---class bottle ap 0.0---
# ---class bus ap 0.0--- (no predictions for this class)
# ---class car ap 0.2748205596944392---
# ---class cat ap 0.036312849162011177---
# ---class chair ap 0.053725573101828544---
# ---class cow ap 0.0--- (no predictions for this class)
# ---class diningtable ap 0.0--- (no predictions for this class)
# ---class dog ap 0.006134969325153374---
# ---class horse ap 0.008620689655172414---
# ---class motorbike ap 0.06699089152824927---
# ---class person ap 0.1932331212239436---
# ---class pottedplant ap 0.0068142361111111095---
# ---class sheep ap 0.0--- (no predictions for this class)
# ---class sofa ap 0.0--- (no predictions for this class)
# ---class train ap 0.0--- (no predictions for this class)
# ---class tvmonitor ap 0.08356279015225854---
# ---map 0.046924426905799684---
# 4 [np.float64(0.017543859649122806), np.float64(0.10852847961393561), np.float64(0.08220051889876803), 0.0, np.float64(0.0), 0.0, np.float64(0.2748205596944392), np.float64(0.036312849162011177), np.float64(0.053725573101828544), 0.0, 0.0, np.float64(0.006134969325153374), np.float64(0.008620689655172414), np.float64(0.06699089152824927), np.float64(0.1932331212239436), np.float64(0.0068142361111111095), 0.0, 0.0, 0.0, np.float64(0.08356279015225854)]
# Updating best test loss: 3.91518
#
#
# Starting epoch 6 / 50
# Learning Rate for this epoch: 0.0015
# Epoch [6/50], Iter [50/279], Loss: total=3.750, reg=1.745, containing_obj=0.778, no_obj=0.091, cls=1.136
# Epoch [6/50], Iter [100/279], Loss: total=3.707, reg=1.750, containing_obj=0.763, no_obj=0.092, cls=1.102
# Epoch [6/50], Iter [150/279], Loss: total=3.681, reg=1.748, containing_obj=0.762, no_obj=0.094, cls=1.077
# Epoch [6/50], Iter [200/279], Loss: total=3.733, reg=1.773, containing_obj=0.774, no_obj=0.095, cls=1.091
# Epoch [6/50], Iter [250/279], Loss: total=3.719, reg=1.778, containing_obj=0.773, no_obj=0.094, cls=1.075
# Updating best test loss: 3.65138
#
#
# Starting epoch 7 / 50
# Learning Rate for this epoch: 0.0015
# Epoch [7/50], Iter [50/279], Loss: total=3.469, reg=1.686, containing_obj=0.751, no_obj=0.095, cls=0.938
# Epoch [7/50], Iter [100/279], Loss: total=3.467, reg=1.681, containing_obj=0.769, no_obj=0.094, cls=0.923
# Epoch [7/50], Iter [150/279], Loss: total=3.489, reg=1.703, containing_obj=0.764, no_obj=0.096, cls=0.925
# Epoch [7/50], Iter [200/279], Loss: total=3.457, reg=1.692, containing_obj=0.764, no_obj=0.098, cls=0.903
# Epoch [7/50], Iter [250/279], Loss: total=3.472, reg=1.706, containing_obj=0.770, no_obj=0.098, cls=0.898
# Updating best test loss: 3.46485
#
#
# Starting epoch 8 / 50
# Learning Rate for this epoch: 0.0015
# Epoch [8/50], Iter [50/279], Loss: total=3.287, reg=1.622, containing_obj=0.762, no_obj=0.100, cls=0.804
# Epoch [8/50], Iter [100/279], Loss: total=3.328, reg=1.644, containing_obj=0.784, no_obj=0.099, cls=0.801
# Epoch [8/50], Iter [150/279], Loss: total=3.318, reg=1.645, containing_obj=0.780, no_obj=0.100, cls=0.792
# Epoch [8/50], Iter [200/279], Loss: total=3.305, reg=1.641, containing_obj=0.778, no_obj=0.101, cls=0.786
# Epoch [8/50], Iter [250/279], Loss: total=3.284, reg=1.634, containing_obj=0.772, no_obj=0.102, cls=0.776
# Updating best test loss: 3.35044
#
#
# Starting epoch 9 / 50
# Learning Rate for this epoch: 0.0015
# Epoch [9/50], Iter [50/279], Loss: total=3.243, reg=1.610, containing_obj=0.787, no_obj=0.108, cls=0.739
# Epoch [9/50], Iter [100/279], Loss: total=3.153, reg=1.573, containing_obj=0.771, no_obj=0.107, cls=0.702
# Epoch [9/50], Iter [150/279], Loss: total=3.169, reg=1.589, containing_obj=0.770, no_obj=0.108, cls=0.703
# Epoch [9/50], Iter [200/279], Loss: total=3.154, reg=1.590, containing_obj=0.765, no_obj=0.108, cls=0.691
# Epoch [9/50], Iter [250/279], Loss: total=3.133, reg=1.578, containing_obj=0.765, no_obj=0.110, cls=0.680
# Updating best test loss: 3.27822
#
#
# Starting epoch 10 / 50
# Learning Rate for this epoch: 0.0015
# Epoch [10/50], Iter [50/279], Loss: total=3.045, reg=1.538, containing_obj=0.786, no_obj=0.119, cls=0.602
# Epoch [10/50], Iter [100/279], Loss: total=3.006, reg=1.516, containing_obj=0.761, no_obj=0.118, cls=0.610
# Epoch [10/50], Iter [150/279], Loss: total=2.985, reg=1.498, containing_obj=0.755, no_obj=0.118, cls=0.614
# Epoch [10/50], Iter [200/279], Loss: total=3.013, reg=1.518, containing_obj=0.761, no_obj=0.118, cls=0.617
# Epoch [10/50], Iter [250/279], Loss: total=3.036, reg=1.528, containing_obj=0.767, no_obj=0.119, cls=0.623
# ---Evaluate model on test samples---
# 100%|██████████| 4950/4950 [01:46<00:00, 46.68it/s]
# ---class aeroplane ap 0.35411796012173413---
# ---class bicycle ap 0.39307963882233826---
# ---class bird ap 0.2677707761894331---
# ---class boat ap 0.1005475782094498---
# ---class bottle ap 0.05044484984019342---
# ---class bus ap 0.3630602466222298---
# ---class car ap 0.5301233767248199---
# ---class cat ap 0.4191979409338873---
# ---class chair ap 0.17428603871156417---
# ---class cow ap 0.07992610553619862---
# ---class diningtable ap 0.05489194144699269---
# ---class dog ap 0.4626545299493753---
# ---class horse ap 0.41802043329759336---
# ---class motorbike ap 0.4185654841436606---
# ---class person ap 0.29537065390133577---
# ---class pottedplant ap 0.07788918128574804---
# ---class sheep ap 0.2934793582350497---
# ---class sofa ap 0.1220133221913244---
# ---class train ap 0.44924839018047824---
# ---class tvmonitor ap 0.30706242090883384---
# ---map 0.28158751136261206---
# 9 [np.float64(0.35411796012173413), np.float64(0.39307963882233826), np.float64(0.2677707761894331), np.float64(0.1005475782094498), np.float64(0.05044484984019342), np.float64(0.3630602466222298), np.float64(0.5301233767248199), np.float64(0.4191979409338873), np.float64(0.17428603871156417), np.float64(0.07992610553619862), np.float64(0.05489194144699269), np.float64(0.4626545299493753), np.float64(0.41802043329759336), np.float64(0.4185654841436606), np.float64(0.29537065390133577), np.float64(0.07788918128574804), np.float64(0.2934793582350497), np.float64(0.1220133221913244), np.float64(0.44924839018047824), np.float64(0.30706242090883384)]
# Updating best test loss: 3.13857
#
#
# Starting epoch 11 / 50
# Learning Rate for this epoch: 0.0015
# Epoch [11/50], Iter [50/279], Loss: total=2.983, reg=1.495, containing_obj=0.791, no_obj=0.115, cls=0.582
# Epoch [11/50], Iter [100/279], Loss: total=2.898, reg=1.456, containing_obj=0.760, no_obj=0.122, cls=0.560
# Epoch [11/50], Iter [150/279], Loss: total=2.909, reg=1.465, containing_obj=0.762, no_obj=0.124, cls=0.558
# Epoch [11/50], Iter [200/279], Loss: total=2.890, reg=1.464, containing_obj=0.753, no_obj=0.126, cls=0.548
# Epoch [11/50], Iter [250/279], Loss: total=2.912, reg=1.476, containing_obj=0.755, no_obj=0.127, cls=0.553
# Updating best test loss: 3.09568
#
#
# Starting epoch 12 / 50
# Learning Rate for this epoch: 0.0015
# Epoch [12/50], Iter [50/279], Loss: total=2.782, reg=1.422, containing_obj=0.741, no_obj=0.135, cls=0.485
# Epoch [12/50], Iter [100/279], Loss: total=2.810, reg=1.436, containing_obj=0.729, no_obj=0.138, cls=0.506
# Epoch [12/50], Iter [150/279], Loss: total=2.797, reg=1.422, containing_obj=0.728, no_obj=0.138, cls=0.510
# Epoch [12/50], Iter [200/279], Loss: total=2.792, reg=1.423, containing_obj=0.726, no_obj=0.141, cls=0.502
# Epoch [12/50], Iter [250/279], Loss: total=2.816, reg=1.435, containing_obj=0.730, no_obj=0.141, cls=0.510
# Updating best test loss: 2.99714
#
#
# Starting epoch 13 / 50
# Learning Rate for this epoch: 0.0015
# Epoch [13/50], Iter [50/279], Loss: total=2.741, reg=1.417, containing_obj=0.713, no_obj=0.142, cls=0.469
# Epoch [13/50], Iter [100/279], Loss: total=2.771, reg=1.423, containing_obj=0.721, no_obj=0.146, cls=0.480
# Epoch [13/50], Iter [150/279], Loss: total=2.723, reg=1.405, containing_obj=0.712, no_obj=0.148, cls=0.458
# Epoch [13/50], Iter [200/279], Loss: total=2.741, reg=1.413, containing_obj=0.713, no_obj=0.151, cls=0.464
# Epoch [13/50], Iter [250/279], Loss: total=2.730, reg=1.408, containing_obj=0.710, no_obj=0.149, cls=0.463
# Updating best test loss: 2.95531
#
#
# Starting epoch 14 / 50
# Learning Rate for this epoch: 0.0015
# Epoch [14/50], Iter [50/279], Loss: total=2.812, reg=1.472, containing_obj=0.726, no_obj=0.148, cls=0.466
# Epoch [14/50], Iter [100/279], Loss: total=2.756, reg=1.428, containing_obj=0.729, no_obj=0.149, cls=0.451
# Epoch [14/50], Iter [150/279], Loss: total=2.690, reg=1.388, containing_obj=0.708, no_obj=0.151, cls=0.443
# Epoch [14/50], Iter [200/279], Loss: total=2.686, reg=1.393, containing_obj=0.711, no_obj=0.149, cls=0.433
# Epoch [14/50], Iter [250/279], Loss: total=2.685, reg=1.389, containing_obj=0.711, no_obj=0.151, cls=0.434
# Updating best test loss: 2.89644
#
#
# Starting epoch 15 / 50
# Learning Rate for this epoch: 0.0015
# Epoch [15/50], Iter [50/279], Loss: total=2.710, reg=1.409, containing_obj=0.724, no_obj=0.161, cls=0.416
# Epoch [15/50], Iter [100/279], Loss: total=2.640, reg=1.361, containing_obj=0.703, no_obj=0.160, cls=0.416
# Epoch [15/50], Iter [150/279], Loss: total=2.616, reg=1.345, containing_obj=0.700, no_obj=0.158, cls=0.414
# Epoch [15/50], Iter [200/279], Loss: total=2.614, reg=1.343, containing_obj=0.698, no_obj=0.157, cls=0.416
# Epoch [15/50], Iter [250/279], Loss: total=2.604, reg=1.333, containing_obj=0.699, no_obj=0.158, cls=0.415
# ---Evaluate model on test samples---
# 100%|██████████| 4950/4950 [01:47<00:00, 45.96it/s]
# ---class aeroplane ap 0.4474392503479822---
# ---class bicycle ap 0.42505706214260053---
# ---class bird ap 0.3522857592663875---
# ---class boat ap 0.14821089112639477---
# ---class bottle ap 0.07137745735110075---
# ---class bus ap 0.5285282849727343---
# ---class car ap 0.5363245661355072---
# ---class cat ap 0.5304891185964585---
# ---class chair ap 0.2368299595379435---
# ---class cow ap 0.301695878450186---
# ---class diningtable ap 0.13012663167791913---
# ---class dog ap 0.5255528435417129---
# ---class horse ap 0.5671211661032698---
# ---class motorbike ap 0.4426509462688576---
# ---class person ap 0.37312933781895546---
# ---class pottedplant ap 0.1374578565515418---
# ---class sheep ap 0.27318559043040136---
# ---class sofa ap 0.30853320245901034---
# ---class train ap 0.5277957238105377---
# ---class tvmonitor ap 0.301223033077836---
# ---map 0.3582507279833668---
# 14 [np.float64(0.4474392503479822), np.float64(0.42505706214260053), np.float64(0.3522857592663875), np.float64(0.14821089112639477), np.float64(0.07137745735110075), np.float64(0.5285282849727343), np.float64(0.5363245661355072), np.float64(0.5304891185964585), np.float64(0.2368299595379435), np.float64(0.301695878450186), np.float64(0.13012663167791913), np.float64(0.5255528435417129), np.float64(0.5671211661032698), np.float64(0.4426509462688576), np.float64(0.37312933781895546), np.float64(0.1374578565515418), np.float64(0.27318559043040136), np.float64(0.30853320245901034), np.float64(0.5277957238105377), np.float64(0.301223033077836)]
# Updating best test loss: 2.87518
#
#
# Starting epoch 16 / 50
# Learning Rate for this epoch: 0.0015
# Epoch [16/50], Iter [50/279], Loss: total=2.594, reg=1.330, containing_obj=0.705, no_obj=0.166, cls=0.393
# Epoch [16/50], Iter [100/279], Loss: total=2.592, reg=1.329, containing_obj=0.701, no_obj=0.168, cls=0.394
# Epoch [16/50], Iter [150/279], Loss: total=2.540, reg=1.304, containing_obj=0.694, no_obj=0.167, cls=0.375
# Epoch [16/50], Iter [200/279], Loss: total=2.544, reg=1.304, containing_obj=0.695, no_obj=0.165, cls=0.380
# Epoch [16/50], Iter [250/279], Loss: total=2.554, reg=1.314, containing_obj=0.696, no_obj=0.164, cls=0.380
# Updating best test loss: 2.85956
#
#
# Starting epoch 17 / 50
# Learning Rate for this epoch: 0.0015
# Epoch [17/50], Iter [50/279], Loss: total=2.353, reg=1.231, containing_obj=0.656, no_obj=0.161, cls=0.304
# Epoch [17/50], Iter [100/279], Loss: total=2.423, reg=1.247, containing_obj=0.672, no_obj=0.163, cls=0.341
# Epoch [17/50], Iter [150/279], Loss: total=2.477, reg=1.272, containing_obj=0.690, no_obj=0.163, cls=0.353
# Epoch [17/50], Iter [200/279], Loss: total=2.452, reg=1.255, containing_obj=0.681, no_obj=0.164, cls=0.351
# Epoch [17/50], Iter [250/279], Loss: total=2.448, reg=1.253, containing_obj=0.681, no_obj=0.164, cls=0.350
# Updating best test loss: 2.80389
#
#
# Starting epoch 18 / 50
# Learning Rate for this epoch: 0.0015
# Epoch [18/50], Iter [50/279], Loss: total=2.309, reg=1.140, containing_obj=0.679, no_obj=0.161, cls=0.330
# Epoch [18/50], Iter [100/279], Loss: total=2.443, reg=1.231, containing_obj=0.699, no_obj=0.164, cls=0.349
# Epoch [18/50], Iter [150/279], Loss: total=2.437, reg=1.246, containing_obj=0.685, no_obj=0.166, cls=0.340
# Epoch [18/50], Iter [200/279], Loss: total=2.450, reg=1.254, containing_obj=0.688, no_obj=0.165, cls=0.343
# Epoch [18/50], Iter [250/279], Loss: total=2.462, reg=1.267, containing_obj=0.685, no_obj=0.165, cls=0.345
# Updating best test loss: 2.77778
#
#
# Starting epoch 19 / 50
# Learning Rate for this epoch: 0.0015
# Epoch [19/50], Iter [50/279], Loss: total=2.300, reg=1.140, containing_obj=0.680, no_obj=0.167, cls=0.313
# Epoch [19/50], Iter [100/279], Loss: total=2.365, reg=1.190, containing_obj=0.690, no_obj=0.166, cls=0.318
# Epoch [19/50], Iter [150/279], Loss: total=2.376, reg=1.197, containing_obj=0.696, no_obj=0.167, cls=0.315
# Epoch [19/50], Iter [200/279], Loss: total=2.375, reg=1.198, containing_obj=0.691, no_obj=0.168, cls=0.318
# Epoch [19/50], Iter [250/279], Loss: total=2.381, reg=1.204, containing_obj=0.688, no_obj=0.170, cls=0.319
# Updating best test loss: 2.75909
#
#
# Starting epoch 20 / 50
# Learning Rate for this epoch: 0.0015
# Epoch [20/50], Iter [50/279], Loss: total=2.315, reg=1.204, containing_obj=0.669, no_obj=0.175, cls=0.267
# Epoch [20/50], Iter [100/279], Loss: total=2.331, reg=1.204, containing_obj=0.664, no_obj=0.174, cls=0.290
# Epoch [20/50], Iter [150/279], Loss: total=2.322, reg=1.190, containing_obj=0.661, no_obj=0.175, cls=0.296
# Epoch [20/50], Iter [200/279], Loss: total=2.332, reg=1.191, containing_obj=0.664, no_obj=0.175, cls=0.303
# Epoch [20/50], Iter [250/279], Loss: total=2.343, reg=1.193, containing_obj=0.664, no_obj=0.174, cls=0.312
# ---Evaluate model on test samples---
# 100%|██████████| 4950/4950 [01:46<00:00, 46.29it/s]
# ---class aeroplane ap 0.38296633697812354---
# ---class bicycle ap 0.5283240445888646---
# ---class bird ap 0.4705833810595628---
# ---class boat ap 0.2676478966754249---
# ---class bottle ap 0.09571611147921116---
# ---class bus ap 0.6203447342972065---
# ---class car ap 0.6162099978232196---
# ---class cat ap 0.6266273115362475---
# ---class chair ap 0.2281609769738493---
# ---class cow ap 0.4895500287498401---
# ---class diningtable ap 0.2435306937079838---
# ---class dog ap 0.6102989373591645---
# ---class horse ap 0.6035055819192363---
# ---class motorbike ap 0.5301501576061074---
# ---class person ap 0.4713945087711452---
# ---class pottedplant ap 0.18257232393377887---
# ---class sheep ap 0.4708068077453246---
# ---class sofa ap 0.3765121107826001---
# ---class train ap 0.5966354187571683---
# ---class tvmonitor ap 0.41906834286343825---
# ---map 0.4415302851803748---
# 19 [np.float64(0.38296633697812354), np.float64(0.5283240445888646), np.float64(0.4705833810595628), np.float64(0.2676478966754249), np.float64(0.09571611147921116), np.float64(0.6203447342972065), np.float64(0.6162099978232196), np.float64(0.6266273115362475), np.float64(0.2281609769738493), np.float64(0.4895500287498401), np.float64(0.2435306937079838), np.float64(0.6102989373591645), np.float64(0.6035055819192363), np.float64(0.5301501576061074), np.float64(0.4713945087711452), np.float64(0.18257232393377887), np.float64(0.4708068077453246), np.float64(0.3765121107826001), np.float64(0.5966354187571683), np.float64(0.41906834286343825)]
# Updating best test loss: 2.71321
#
#
# Starting epoch 21 / 50
# Learning Rate for this epoch: 0.0015
# Epoch [21/50], Iter [50/279], Loss: total=2.226, reg=1.114, containing_obj=0.652, no_obj=0.176, cls=0.285
# Epoch [21/50], Iter [100/279], Loss: total=2.279, reg=1.150, containing_obj=0.657, no_obj=0.177, cls=0.295
# Epoch [21/50], Iter [150/279], Loss: total=2.327, reg=1.195, containing_obj=0.660, no_obj=0.176, cls=0.297
# Epoch [21/50], Iter [200/279], Loss: total=2.311, reg=1.186, containing_obj=0.656, no_obj=0.175, cls=0.293
# Epoch [21/50], Iter [250/279], Loss: total=2.313, reg=1.186, containing_obj=0.655, no_obj=0.176, cls=0.296
# Updating best test loss: 2.69706
#
#
# Starting epoch 22 / 50
# Learning Rate for this epoch: 0.0015
# Epoch [22/50], Iter [50/279], Loss: total=2.312, reg=1.175, containing_obj=0.674, no_obj=0.176, cls=0.286
# Epoch [22/50], Iter [100/279], Loss: total=2.268, reg=1.159, containing_obj=0.651, no_obj=0.175, cls=0.284
# Epoch [22/50], Iter [150/279], Loss: total=2.292, reg=1.169, containing_obj=0.659, no_obj=0.176, cls=0.289
# Epoch [22/50], Iter [200/279], Loss: total=2.281, reg=1.161, containing_obj=0.664, no_obj=0.175, cls=0.281
# Epoch [22/50], Iter [250/279], Loss: total=2.271, reg=1.158, containing_obj=0.660, no_obj=0.176, cls=0.278
#
#
# Starting epoch 23 / 50
# Learning Rate for this epoch: 0.0015
# Epoch [23/50], Iter [50/279], Loss: total=2.233, reg=1.119, containing_obj=0.663, no_obj=0.177, cls=0.274
# Epoch [23/50], Iter [100/279], Loss: total=2.221, reg=1.129, containing_obj=0.648, no_obj=0.180, cls=0.263
# Epoch [23/50], Iter [150/279], Loss: total=2.188, reg=1.112, containing_obj=0.639, no_obj=0.180, cls=0.257
# Epoch [23/50], Iter [200/279], Loss: total=2.208, reg=1.120, containing_obj=0.648, no_obj=0.177, cls=0.263
# Epoch [23/50], Iter [250/279], Loss: total=2.216, reg=1.127, containing_obj=0.649, no_obj=0.178, cls=0.262
# Updating best test loss: 2.64385
#
#
# Starting epoch 24 / 50
# Learning Rate for this epoch: 0.0015
# Epoch [24/50], Iter [50/279], Loss: total=2.150, reg=1.090, containing_obj=0.653, no_obj=0.180, cls=0.227
# Epoch [24/50], Iter [100/279], Loss: total=2.192, reg=1.106, containing_obj=0.657, no_obj=0.185, cls=0.243
# Epoch [24/50], Iter [150/279], Loss: total=2.182, reg=1.106, containing_obj=0.650, no_obj=0.184, cls=0.242
# Epoch [24/50], Iter [200/279], Loss: total=2.167, reg=1.090, containing_obj=0.647, no_obj=0.183, cls=0.247
# Epoch [24/50], Iter [250/279], Loss: total=2.167, reg=1.098, containing_obj=0.643, no_obj=0.181, cls=0.245
#
#
# Starting epoch 25 / 50
# Learning Rate for this epoch: 0.0015
# Epoch [25/50], Iter [50/279], Loss: total=2.146, reg=1.082, containing_obj=0.652, no_obj=0.171, cls=0.242
# Epoch [25/50], Iter [100/279], Loss: total=2.136, reg=1.066, containing_obj=0.655, no_obj=0.176, cls=0.240
# Epoch [25/50], Iter [150/279], Loss: total=2.135, reg=1.075, containing_obj=0.649, no_obj=0.177, cls=0.235
# Epoch [25/50], Iter [200/279], Loss: total=2.156, reg=1.089, containing_obj=0.650, no_obj=0.180, cls=0.237
# Epoch [25/50], Iter [250/279], Loss: total=2.141, reg=1.077, containing_obj=0.648, no_obj=0.182, cls=0.234
# ---Evaluate model on test samples---
# 100%|██████████| 4950/4950 [01:46<00:00, 46.41it/s]
# ---class aeroplane ap 0.5178187195208815---
# ---class bicycle ap 0.5967100910299805---
# ---class bird ap 0.4867540626523085---
# ---class boat ap 0.3154700011986974---
# ---class bottle ap 0.151034474414331---
# ---class bus ap 0.555268400819108---
# ---class car ap 0.5794571884229396---
# ---class cat ap 0.6643827295980591---
# ---class chair ap 0.26291016265460915---
# ---class cow ap 0.5194314125171757---
# ---class diningtable ap 0.27659534236266975---
# ---class dog ap 0.6015570927174115---
# ---class horse ap 0.6961133793486809---
# ---class motorbike ap 0.5257783675295019---
# ---class person ap 0.4644781832377756---
# ---class pottedplant ap 0.17512102426452575---
# ---class sheep ap 0.5256120586422252---
# ---class sofa ap 0.46608648484771875---
# ---class train ap 0.612674140323501---
# ---class tvmonitor ap 0.41748117527598105---
# ---map 0.47053672456890405---
# 24 [np.float64(0.5178187195208815), np.float64(0.5967100910299805), np.float64(0.4867540626523085), np.float64(0.3154700011986974), np.float64(0.151034474414331), np.float64(0.555268400819108), np.float64(0.5794571884229396), np.float64(0.6643827295980591), np.float64(0.26291016265460915), np.float64(0.5194314125171757), np.float64(0.27659534236266975), np.float64(0.6015570927174115), np.float64(0.6961133793486809), np.float64(0.5257783675295019), np.float64(0.4644781832377756), np.float64(0.17512102426452575), np.float64(0.5256120586422252), np.float64(0.46608648484771875), np.float64(0.612674140323501), np.float64(0.41748117527598105)]
#
#
# Starting epoch 26 / 50
# Learning Rate for this epoch: 0.0015
# Epoch [26/50], Iter [50/279], Loss: total=2.061, reg=1.012, containing_obj=0.634, no_obj=0.180, cls=0.235
# Epoch [26/50], Iter [100/279], Loss: total=2.121, reg=1.050, containing_obj=0.650, no_obj=0.177, cls=0.243
# Epoch [26/50], Iter [150/279], Loss: total=2.133, reg=1.061, containing_obj=0.644, no_obj=0.183, cls=0.245
# Epoch [26/50], Iter [200/279], Loss: total=2.111, reg=1.054, containing_obj=0.637, no_obj=0.183, cls=0.237
# Epoch [26/50], Iter [250/279], Loss: total=2.111, reg=1.054, containing_obj=0.636, no_obj=0.183, cls=0.237
# Updating best test loss: 2.62828
#
#
# Starting epoch 27 / 50
# Learning Rate for this epoch: 0.0015
# Epoch [27/50], Iter [50/279], Loss: total=2.103, reg=1.041, containing_obj=0.609, no_obj=0.195, cls=0.258
# Epoch [27/50], Iter [100/279], Loss: total=2.119, reg=1.069, containing_obj=0.617, no_obj=0.186, cls=0.246
# Epoch [27/50], Iter [150/279], Loss: total=2.137, reg=1.068, containing_obj=0.624, no_obj=0.187, cls=0.259
# Epoch [27/50], Iter [200/279], Loss: total=2.147, reg=1.077, containing_obj=0.633, no_obj=0.187, cls=0.251
# Epoch [27/50], Iter [250/279], Loss: total=2.114, reg=1.055, containing_obj=0.627, no_obj=0.188, cls=0.243
# Updating best test loss: 2.61038
#
#
# Starting epoch 28 / 50
# Learning Rate for this epoch: 0.0015
# Epoch [28/50], Iter [50/279], Loss: total=2.120, reg=1.096, containing_obj=0.613, no_obj=0.189, cls=0.223
# Epoch [28/50], Iter [100/279], Loss: total=2.078, reg=1.051, containing_obj=0.620, no_obj=0.185, cls=0.223
# Epoch [28/50], Iter [150/279], Loss: total=2.060, reg=1.035, containing_obj=0.618, no_obj=0.185, cls=0.222
# Epoch [28/50], Iter [200/279], Loss: total=2.074, reg=1.046, containing_obj=0.624, no_obj=0.187, cls=0.218
# Epoch [28/50], Iter [250/279], Loss: total=2.067, reg=1.045, containing_obj=0.620, no_obj=0.185, cls=0.216
# Updating best test loss: 2.60939
#
#
# Starting epoch 29 / 50
# Learning Rate for this epoch: 0.0015
# Epoch [29/50], Iter [50/279], Loss: total=2.148, reg=1.098, containing_obj=0.645, no_obj=0.190, cls=0.215
# Epoch [29/50], Iter [100/279], Loss: total=2.106, reg=1.060, containing_obj=0.639, no_obj=0.194, cls=0.213
# Epoch [29/50], Iter [150/279], Loss: total=2.060, reg=1.026, containing_obj=0.631, no_obj=0.190, cls=0.213
# Epoch [29/50], Iter [200/279], Loss: total=2.060, reg=1.026, containing_obj=0.624, no_obj=0.190, cls=0.220
# Epoch [29/50], Iter [250/279], Loss: total=2.053, reg=1.029, containing_obj=0.620, no_obj=0.189, cls=0.216
#
#
# Starting epoch 30 / 50
# Learning Rate for this epoch: 0.0015
# Epoch [30/50], Iter [50/279], Loss: total=1.939, reg=0.946, containing_obj=0.585, no_obj=0.189, cls=0.219
# Epoch [30/50], Iter [100/279], Loss: total=1.988, reg=0.974, containing_obj=0.616, no_obj=0.186, cls=0.213
# Epoch [30/50], Iter [150/279], Loss: total=1.995, reg=0.983, containing_obj=0.619, no_obj=0.189, cls=0.203
# Epoch [30/50], Iter [200/279], Loss: total=2.003, reg=0.988, containing_obj=0.623, no_obj=0.189, cls=0.204
# Epoch [30/50], Iter [250/279], Loss: total=1.997, reg=0.978, containing_obj=0.623, no_obj=0.187, cls=0.209
# ---Evaluate model on test samples---
# 100%|██████████| 4950/4950 [01:47<00:00, 46.06it/s]
# ---class aeroplane ap 0.5309568910204499---
# ---class bicycle ap 0.6209548449420444---
# ---class bird ap 0.45319403369518196---
# ---class boat ap 0.34069737358519303---
# ---class bottle ap 0.1616479849227658---
# ---class bus ap 0.5812653849388489---
# ---class car ap 0.6396693777585851---
# ---class cat ap 0.6919487038397067---
# ---class chair ap 0.28215275682448576---
# ---class cow ap 0.5901757167478827---
# ---class diningtable ap 0.37274979989196044---
# ---class dog ap 0.6598384740576124---
# ---class horse ap 0.6581230967996616---
# ---class motorbike ap 0.5165152032704055---
# ---class person ap 0.47079318612255155---
# ---class pottedplant ap 0.1981512942733908---
# ---class sheep ap 0.5560380272496244---
# ---class sofa ap 0.4927058210483677---
# ---class train ap 0.661974418953853---
# ---class tvmonitor ap 0.5126522680409806---
# ---map 0.49961023289917766---
# 29 [np.float64(0.5309568910204499), np.float64(0.6209548449420444), np.float64(0.45319403369518196), np.float64(0.34069737358519303), np.float64(0.1616479849227658), np.float64(0.5812653849388489), np.float64(0.6396693777585851), np.float64(0.6919487038397067), np.float64(0.28215275682448576), np.float64(0.5901757167478827), np.float64(0.37274979989196044), np.float64(0.6598384740576124), np.float64(0.6581230967996616), np.float64(0.5165152032704055), np.float64(0.47079318612255155), np.float64(0.1981512942733908), np.float64(0.5560380272496244), np.float64(0.4927058210483677), np.float64(0.661974418953853), np.float64(0.5126522680409806)]
#
#
# Starting epoch 31 / 50
# Learning Rate for this epoch: 0.00015000000000000001
# Epoch [31/50], Iter [50/279], Loss: total=1.910, reg=0.926, containing_obj=0.593, no_obj=0.201, cls=0.190
# Epoch [31/50], Iter [100/279], Loss: total=1.906, reg=0.921, containing_obj=0.597, no_obj=0.198, cls=0.190
# Epoch [31/50], Iter [150/279], Loss: total=1.932, reg=0.945, containing_obj=0.603, no_obj=0.196, cls=0.189
# Epoch [31/50], Iter [200/279], Loss: total=1.914, reg=0.928, containing_obj=0.600, no_obj=0.196, cls=0.189
# Epoch [31/50], Iter [250/279], Loss: total=1.920, reg=0.937, containing_obj=0.599, no_obj=0.195, cls=0.189
# Updating best test loss: 2.55262
#
#
# Starting epoch 32 / 50
# Learning Rate for this epoch: 0.00015000000000000001
# Epoch [32/50], Iter [50/279], Loss: total=1.976, reg=0.990, containing_obj=0.611, no_obj=0.194, cls=0.181
# Epoch [32/50], Iter [100/279], Loss: total=1.919, reg=0.948, containing_obj=0.599, no_obj=0.191, cls=0.180
# Epoch [32/50], Iter [150/279], Loss: total=1.900, reg=0.945, containing_obj=0.588, no_obj=0.194, cls=0.174
# Epoch [32/50], Iter [200/279], Loss: total=1.901, reg=0.943, containing_obj=0.590, no_obj=0.193, cls=0.175
# Epoch [32/50], Iter [250/279], Loss: total=1.917, reg=0.950, containing_obj=0.595, no_obj=0.194, cls=0.178
# Updating best test loss: 2.54273
#
#
# Starting epoch 33 / 50
# Learning Rate for this epoch: 0.00015000000000000001
# Epoch [33/50], Iter [50/279], Loss: total=1.995, reg=0.971, containing_obj=0.645, no_obj=0.191, cls=0.187
# Epoch [33/50], Iter [100/279], Loss: total=1.992, reg=0.988, containing_obj=0.622, no_obj=0.192, cls=0.189
# Epoch [33/50], Iter [150/279], Loss: total=1.903, reg=0.940, containing_obj=0.591, no_obj=0.194, cls=0.178
# Epoch [33/50], Iter [200/279], Loss: total=1.880, reg=0.923, containing_obj=0.589, no_obj=0.192, cls=0.175
# Epoch [33/50], Iter [250/279], Loss: total=1.896, reg=0.936, containing_obj=0.592, no_obj=0.192, cls=0.175
# Updating best test loss: 2.53089
#
#
# Starting epoch 34 / 50
# Learning Rate for this epoch: 0.00015000000000000001
# Epoch [34/50], Iter [50/279], Loss: total=1.864, reg=0.907, containing_obj=0.580, no_obj=0.195, cls=0.182
# Epoch [34/50], Iter [100/279], Loss: total=1.856, reg=0.903, containing_obj=0.585, no_obj=0.195, cls=0.173
# Epoch [34/50], Iter [150/279], Loss: total=1.813, reg=0.875, containing_obj=0.574, no_obj=0.196, cls=0.169
# Epoch [34/50], Iter [200/279], Loss: total=1.826, reg=0.879, containing_obj=0.581, no_obj=0.197, cls=0.168
# Epoch [34/50], Iter [250/279], Loss: total=1.848, reg=0.894, containing_obj=0.589, no_obj=0.196, cls=0.170
#
#
# Starting epoch 35 / 50
# Learning Rate for this epoch: 0.00015000000000000001
# Epoch [35/50], Iter [50/279], Loss: total=1.891, reg=0.945, containing_obj=0.595, no_obj=0.195, cls=0.156
# Epoch [35/50], Iter [100/279], Loss: total=1.881, reg=0.927, containing_obj=0.594, no_obj=0.197, cls=0.163
# Epoch [35/50], Iter [150/279], Loss: total=1.843, reg=0.907, containing_obj=0.583, no_obj=0.195, cls=0.159
# Epoch [35/50], Iter [200/279], Loss: total=1.831, reg=0.895, containing_obj=0.580, no_obj=0.194, cls=0.161
# Epoch [35/50], Iter [250/279], Loss: total=1.834, reg=0.894, containing_obj=0.585, no_obj=0.194, cls=0.161
# ---Evaluate model on test samples---
# 100%|██████████| 4950/4950 [01:46<00:00, 46.30it/s]
# ---class aeroplane ap 0.5295335277948112---
# ---class bicycle ap 0.6307898256483588---
# ---class bird ap 0.4779565736432392---
# ---class boat ap 0.3176245539269653---
# ---class bottle ap 0.18931492353404283---
# ---class bus ap 0.6159452529772454---
# ---class car ap 0.6608592673236764---
# ---class cat ap 0.7178771215109813---
# ---class chair ap 0.2958420024001138---
# ---class cow ap 0.54159723414181---
# ---class diningtable ap 0.39668034545646635---
# ---class dog ap 0.6911700204573119---
# ---class horse ap 0.7008830681032727---
# ---class motorbike ap 0.565183455367541---
# ---class person ap 0.5053886710453606---
# ---class pottedplant ap 0.2086192525114759---
# ---class sheep ap 0.5587621932986389---
# ---class sofa ap 0.47937843174265804---
# ---class train ap 0.6499501524685638---
# ---class tvmonitor ap 0.46474710749481396---
# ---map 0.5099051490423674---
# 34 [np.float64(0.5295335277948112), np.float64(0.6307898256483588), np.float64(0.4779565736432392), np.float64(0.3176245539269653), np.float64(0.18931492353404283), np.float64(0.6159452529772454), np.float64(0.6608592673236764), np.float64(0.7178771215109813), np.float64(0.2958420024001138), np.float64(0.54159723414181), np.float64(0.39668034545646635), np.float64(0.6911700204573119), np.float64(0.7008830681032727), np.float64(0.565183455367541), np.float64(0.5053886710453606), np.float64(0.2086192525114759), np.float64(0.5587621932986389), np.float64(0.47937843174265804), np.float64(0.6499501524685638), np.float64(0.46474710749481396)]
# Updating best test loss: 2.52647
#
#
# Starting epoch 36 / 50
# Learning Rate for this epoch: 0.00015000000000000001
# Epoch [36/50], Iter [50/279], Loss: total=1.956, reg=0.975, containing_obj=0.617, no_obj=0.192, cls=0.172
# Epoch [36/50], Iter [100/279], Loss: total=1.895, reg=0.928, containing_obj=0.610, no_obj=0.190, cls=0.167
# Epoch [36/50], Iter [150/279], Loss: total=1.880, reg=0.921, containing_obj=0.595, no_obj=0.194, cls=0.170
# Epoch [36/50], Iter [200/279], Loss: total=1.860, reg=0.904, containing_obj=0.589, no_obj=0.194, cls=0.173
# Epoch [36/50], Iter [250/279], Loss: total=1.848, reg=0.897, containing_obj=0.585, no_obj=0.194, cls=0.172
# Updating best test loss: 2.52148
#
#
# Starting epoch 37 / 50
# Learning Rate for this epoch: 0.00015000000000000001
# Epoch [37/50], Iter [50/279], Loss: total=1.852, reg=0.905, containing_obj=0.590, no_obj=0.202, cls=0.155
# Epoch [37/50], Iter [100/279], Loss: total=1.847, reg=0.905, containing_obj=0.589, no_obj=0.193, cls=0.160
# Epoch [37/50], Iter [150/279], Loss: total=1.823, reg=0.893, containing_obj=0.576, no_obj=0.195, cls=0.158
# Epoch [37/50], Iter [200/279], Loss: total=1.857, reg=0.915, containing_obj=0.591, no_obj=0.193, cls=0.159
# Epoch [37/50], Iter [250/279], Loss: total=1.837, reg=0.902, containing_obj=0.582, no_obj=0.194, cls=0.160
# Updating best test loss: 2.52072
#
#
# Starting epoch 38 / 50
# Learning Rate for this epoch: 0.00015000000000000001
# Epoch [38/50], Iter [50/279], Loss: total=1.799, reg=0.879, containing_obj=0.576, no_obj=0.189, cls=0.155
# Epoch [38/50], Iter [100/279], Loss: total=1.763, reg=0.851, containing_obj=0.568, no_obj=0.191, cls=0.154
# Epoch [38/50], Iter [150/279], Loss: total=1.800, reg=0.866, containing_obj=0.581, no_obj=0.195, cls=0.159
# Epoch [38/50], Iter [200/279], Loss: total=1.789, reg=0.869, containing_obj=0.568, no_obj=0.195, cls=0.157
# Epoch [38/50], Iter [250/279], Loss: total=1.800, reg=0.871, containing_obj=0.574, no_obj=0.194, cls=0.161
# Updating best test loss: 2.51053
#
#
# Starting epoch 39 / 50
# Learning Rate for this epoch: 0.00015000000000000001
# Epoch [39/50], Iter [50/279], Loss: total=1.857, reg=0.892, containing_obj=0.600, no_obj=0.198, cls=0.168
# Epoch [39/50], Iter [100/279], Loss: total=1.801, reg=0.872, containing_obj=0.569, no_obj=0.199, cls=0.161
# Epoch [39/50], Iter [150/279], Loss: total=1.818, reg=0.885, containing_obj=0.573, no_obj=0.197, cls=0.163
# Epoch [39/50], Iter [200/279], Loss: total=1.822, reg=0.891, containing_obj=0.574, no_obj=0.197, cls=0.160
# Epoch [39/50], Iter [250/279], Loss: total=1.811, reg=0.880, containing_obj=0.578, no_obj=0.194, cls=0.158
#
#
# Starting epoch 40 / 50
# Learning Rate for this epoch: 0.00015000000000000001
# Epoch [40/50], Iter [50/279], Loss: total=1.742, reg=0.844, containing_obj=0.535, no_obj=0.199, cls=0.163
# Epoch [40/50], Iter [100/279], Loss: total=1.823, reg=0.891, containing_obj=0.564, no_obj=0.195, cls=0.173
# Epoch [40/50], Iter [150/279], Loss: total=1.849, reg=0.905, containing_obj=0.579, no_obj=0.192, cls=0.173
# Epoch [40/50], Iter [200/279], Loss: total=1.810, reg=0.887, containing_obj=0.569, no_obj=0.196, cls=0.158
# Epoch [40/50], Iter [250/279], Loss: total=1.790, reg=0.874, containing_obj=0.563, no_obj=0.195, cls=0.158
# ---Evaluate model on test samples---
# 100%|██████████| 4950/4950 [01:47<00:00, 46.17it/s]
# ---class aeroplane ap 0.5836732075872195---
# ---class bicycle ap 0.6442084925089246---
# ---class bird ap 0.4997457894422038---
# ---class boat ap 0.2928314885457124---
# ---class bottle ap 0.1894833186223816---
# ---class bus ap 0.6479853278325192---
# ---class car ap 0.6709645372547628---
# ---class cat ap 0.7317285409635466---
# ---class chair ap 0.30836969996436414---
# ---class cow ap 0.5285599917121123---
# ---class diningtable ap 0.3795564499029953---
# ---class dog ap 0.6911662438788613---
# ---class horse ap 0.6889011339052978---
# ---class motorbike ap 0.5449916218571993---
# ---class person ap 0.5185354483817632---
# ---class pottedplant ap 0.21856252227737163---
# ---class sheep ap 0.5664383134737622---
# ---class sofa ap 0.5103669937171281---
# ---class train ap 0.6636990952045194---
# ---class tvmonitor ap 0.487200141190679---
# ---map 0.5183484179111661---
# 39 [np.float64(0.5836732075872195), np.float64(0.6442084925089246), np.float64(0.4997457894422038), np.float64(0.2928314885457124), np.float64(0.1894833186223816), np.float64(0.6479853278325192), np.float64(0.6709645372547628), np.float64(0.7317285409635466), np.float64(0.30836969996436414), np.float64(0.5285599917121123), np.float64(0.3795564499029953), np.float64(0.6911662438788613), np.float64(0.6889011339052978), np.float64(0.5449916218571993), np.float64(0.5185354483817632), np.float64(0.21856252227737163), np.float64(0.5664383134737622), np.float64(0.5103669937171281), np.float64(0.6636990952045194), np.float64(0.487200141190679)]
#
#
# Starting epoch 41 / 50
# Learning Rate for this epoch: 1.5000000000000002e-05
# Epoch [41/50], Iter [50/279], Loss: total=1.777, reg=0.869, containing_obj=0.557, no_obj=0.194, cls=0.158
# Epoch [41/50], Iter [100/279], Loss: total=1.824, reg=0.877, containing_obj=0.597, no_obj=0.194, cls=0.156
# Epoch [41/50], Iter [150/279], Loss: total=1.822, reg=0.878, containing_obj=0.592, no_obj=0.193, cls=0.158
# Epoch [41/50], Iter [200/279], Loss: total=1.815, reg=0.880, containing_obj=0.586, no_obj=0.192, cls=0.157
# Epoch [41/50], Iter [250/279], Loss: total=1.797, reg=0.871, containing_obj=0.578, no_obj=0.192, cls=0.156
#
#
# Starting epoch 42 / 50
# Learning Rate for this epoch: 1.5000000000000002e-05
# Epoch [42/50], Iter [50/279], Loss: total=1.844, reg=0.902, containing_obj=0.596, no_obj=0.192, cls=0.155
# Epoch [42/50], Iter [100/279], Loss: total=1.808, reg=0.882, containing_obj=0.583, no_obj=0.191, cls=0.152
# Epoch [42/50], Iter [150/279], Loss: total=1.783, reg=0.866, containing_obj=0.575, no_obj=0.192, cls=0.150
# Epoch [42/50], Iter [200/279], Loss: total=1.795, reg=0.870, containing_obj=0.580, no_obj=0.192, cls=0.152
# Epoch [42/50], Iter [250/279], Loss: total=1.796, reg=0.872, containing_obj=0.578, no_obj=0.192, cls=0.153
# Updating best test loss: 2.51005
#
#
# Starting epoch 43 / 50
# Learning Rate for this epoch: 1.5000000000000002e-05
# Epoch [43/50], Iter [50/279], Loss: total=1.724, reg=0.843, containing_obj=0.548, no_obj=0.189, cls=0.145
# Epoch [43/50], Iter [100/279], Loss: total=1.780, reg=0.874, containing_obj=0.551, no_obj=0.195, cls=0.159
# Epoch [43/50], Iter [150/279], Loss: total=1.808, reg=0.886, containing_obj=0.566, no_obj=0.194, cls=0.161
# Epoch [43/50], Iter [200/279], Loss: total=1.797, reg=0.876, containing_obj=0.570, no_obj=0.194, cls=0.157
# Epoch [43/50], Iter [250/279], Loss: total=1.800, reg=0.874, containing_obj=0.572, no_obj=0.196, cls=0.158
#
#
# Starting epoch 44 / 50
# Learning Rate for this epoch: 1.5000000000000002e-05
# Epoch [44/50], Iter [50/279], Loss: total=1.870, reg=0.927, containing_obj=0.583, no_obj=0.199, cls=0.160
# Epoch [44/50], Iter [100/279], Loss: total=1.756, reg=0.860, containing_obj=0.557, no_obj=0.202, cls=0.138
# Epoch [44/50], Iter [150/279], Loss: total=1.790, reg=0.872, containing_obj=0.572, no_obj=0.200, cls=0.146
# Epoch [44/50], Iter [200/279], Loss: total=1.800, reg=0.884, containing_obj=0.570, no_obj=0.197, cls=0.149
# Epoch [44/50], Iter [250/279], Loss: total=1.793, reg=0.878, containing_obj=0.570, no_obj=0.195, cls=0.150
#
#
# Starting epoch 45 / 50
# Learning Rate for this epoch: 1.5000000000000002e-05
# Epoch [45/50], Iter [50/279], Loss: total=1.856, reg=0.902, containing_obj=0.598, no_obj=0.201, cls=0.156
# Epoch [45/50], Iter [100/279], Loss: total=1.854, reg=0.901, containing_obj=0.600, no_obj=0.198, cls=0.156
# Epoch [45/50], Iter [150/279], Loss: total=1.824, reg=0.891, containing_obj=0.585, no_obj=0.195, cls=0.154
# Epoch [45/50], Iter [200/279], Loss: total=1.820, reg=0.890, containing_obj=0.578, no_obj=0.198, cls=0.155
# Epoch [45/50], Iter [250/279], Loss: total=1.810, reg=0.882, containing_obj=0.575, no_obj=0.197, cls=0.156
# ---Evaluate model on test samples---
# 100%|██████████| 4950/4950 [01:47<00:00, 46.24it/s]
# ---class aeroplane ap 0.5603767331842116---
# ---class bicycle ap 0.6475791260249864---
# ---class bird ap 0.5150050377297182---
# ---class boat ap 0.2937617636785722---
# ---class bottle ap 0.16216526631538708---
# ---class bus ap 0.6358441706852584---
# ---class car ap 0.6729658988397846---
# ---class cat ap 0.7193175520146768---
# ---class chair ap 0.32357997820399437---
# ---class cow ap 0.5091987445326571---
# ---class diningtable ap 0.35833891030142867---
# ---class dog ap 0.6937345358656424---
# ---class horse ap 0.6783083568729534---
# ---class motorbike ap 0.5327084222164997---
# ---class person ap 0.5270630551369104---
# ---class pottedplant ap 0.22649415282905444---
# ---class sheep ap 0.5595590497028701---
# ---class sofa ap 0.5041252998965979---
# ---class train ap 0.6496004046078854---
# ---class tvmonitor ap 0.5015113693555331---
# ---map 0.5135618913997311---
# 44 [np.float64(0.5603767331842116), np.float64(0.6475791260249864), np.float64(0.5150050377297182), np.float64(0.2937617636785722), np.float64(0.16216526631538708), np.float64(0.6358441706852584), np.float64(0.6729658988397846), np.float64(0.7193175520146768), np.float64(0.32357997820399437), np.float64(0.5091987445326571), np.float64(0.35833891030142867), np.float64(0.6937345358656424), np.float64(0.6783083568729534), np.float64(0.5327084222164997), np.float64(0.5270630551369104), np.float64(0.22649415282905444), np.float64(0.5595590497028701), np.float64(0.5041252998965979), np.float64(0.6496004046078854), np.float64(0.5015113693555331)]
#
#
# Starting epoch 46 / 50
# Learning Rate for this epoch: 1.5000000000000002e-05
# Epoch [46/50], Iter [50/279], Loss: total=1.781, reg=0.854, containing_obj=0.579, no_obj=0.193, cls=0.155
# Epoch [46/50], Iter [100/279], Loss: total=1.806, reg=0.868, containing_obj=0.586, no_obj=0.190, cls=0.163
# Epoch [46/50], Iter [150/279], Loss: total=1.800, reg=0.867, containing_obj=0.580, no_obj=0.190, cls=0.163
# Epoch [46/50], Iter [200/279], Loss: total=1.794, reg=0.865, containing_obj=0.577, no_obj=0.191, cls=0.160
# Epoch [46/50], Iter [250/279], Loss: total=1.785, reg=0.862, containing_obj=0.574, no_obj=0.193, cls=0.155
# Updating best test loss: 2.50783
#
#
# Starting epoch 47 / 50
# Learning Rate for this epoch: 1.5000000000000002e-05
# Epoch [47/50], Iter [50/279], Loss: total=1.724, reg=0.830, containing_obj=0.555, no_obj=0.192, cls=0.147
# Epoch [47/50], Iter [100/279], Loss: total=1.772, reg=0.870, containing_obj=0.562, no_obj=0.194, cls=0.147
# Epoch [47/50], Iter [150/279], Loss: total=1.750, reg=0.851, containing_obj=0.555, no_obj=0.197, cls=0.147
# Epoch [47/50], Iter [200/279], Loss: total=1.781, reg=0.873, containing_obj=0.565, no_obj=0.194, cls=0.149
# Epoch [47/50], Iter [250/279], Loss: total=1.785, reg=0.875, containing_obj=0.564, no_obj=0.195, cls=0.150
#
#
# Starting epoch 48 / 50
# Learning Rate for this epoch: 1.5000000000000002e-05
# Epoch [48/50], Iter [50/279], Loss: total=1.895, reg=0.944, containing_obj=0.593, no_obj=0.189, cls=0.169
# Epoch [48/50], Iter [100/279], Loss: total=1.870, reg=0.931, containing_obj=0.586, no_obj=0.191, cls=0.161
# Epoch [48/50], Iter [150/279], Loss: total=1.862, reg=0.920, containing_obj=0.585, no_obj=0.196, cls=0.160
# Epoch [48/50], Iter [200/279], Loss: total=1.845, reg=0.913, containing_obj=0.578, no_obj=0.197, cls=0.157
# Epoch [48/50], Iter [250/279], Loss: total=1.816, reg=0.890, containing_obj=0.571, no_obj=0.197, cls=0.158
#
#
# Starting epoch 49 / 50
# Learning Rate for this epoch: 1.5000000000000002e-05
# Epoch [49/50], Iter [50/279], Loss: total=1.818, reg=0.875, containing_obj=0.595, no_obj=0.185, cls=0.163
# Epoch [49/50], Iter [100/279], Loss: total=1.765, reg=0.847, containing_obj=0.571, no_obj=0.195, cls=0.151
# Epoch [49/50], Iter [150/279], Loss: total=1.771, reg=0.856, containing_obj=0.571, no_obj=0.194, cls=0.150
# Epoch [49/50], Iter [200/279], Loss: total=1.781, reg=0.862, containing_obj=0.572, no_obj=0.196, cls=0.151
# Epoch [49/50], Iter [250/279], Loss: total=1.774, reg=0.860, containing_obj=0.568, no_obj=0.196, cls=0.150
# Updating best test loss: 2.49974
#
#
# Starting epoch 50 / 50
# Learning Rate for this epoch: 1.5000000000000002e-05
# Epoch [50/50], Iter [50/279], Loss: total=1.769, reg=0.887, containing_obj=0.550, no_obj=0.188, cls=0.144
# Epoch [50/50], Iter [100/279], Loss: total=1.756, reg=0.885, containing_obj=0.550, no_obj=0.189, cls=0.132
# Epoch [50/50], Iter [150/279], Loss: total=1.782, reg=0.895, containing_obj=0.552, no_obj=0.190, cls=0.144
# Epoch [50/50], Iter [200/279], Loss: total=1.784, reg=0.887, containing_obj=0.561, no_obj=0.191, cls=0.144
# Epoch [50/50], Iter [250/279], Loss: total=1.779, reg=0.879, containing_obj=0.562, no_obj=0.193, cls=0.145
# ---Evaluate model on test samples---
# 100%|██████████| 4950/4950 [01:47<00:00, 46.09it/s]
# ---class aeroplane ap 0.5593786946317048---
# ---class bicycle ap 0.650628463887343---
# ---class bird ap 0.496033109054446---
# ---class boat ap 0.3179856531886345---
# ---class bottle ap 0.18954884946621192---
# ---class bus ap 0.6528829141481661---
# ---class car ap 0.676926705559994---
# ---class cat ap 0.7177419557444841---
# ---class chair ap 0.3055840949062393---
# ---class cow ap 0.5072682008910645---
# ---class diningtable ap 0.40174977556694835---
# ---class dog ap 0.6877403517635892---
# ---class horse ap 0.6979427343799373---
# ---class motorbike ap 0.5907661504073733---
# ---class person ap 0.5263551555119249---
# ---class pottedplant ap 0.22896413328127588---
# ---class sheep ap 0.5784636761548603---
# ---class sofa ap 0.5040946788442211---
# ---class train ap 0.6706051755765687---
# ---class tvmonitor ap 0.48157241967279185---
# ---map 0.5221116446318891---
# 49 [np.float64(0.5593786946317048), np.float64(0.650628463887343), np.float64(0.496033109054446), np.float64(0.3179856531886345), np.float64(0.18954884946621192), np.float64(0.6528829141481661), np.float64(0.676926705559994), np.float64(0.7177419557444841), np.float64(0.3055840949062393), np.float64(0.5072682008910645), np.float64(0.40174977556694835), np.float64(0.6877403517635892), np.float64(0.6979427343799373), np.float64(0.5907661504073733), np.float64(0.5263551555119249), np.float64(0.22896413328127588), np.float64(0.5784636761548603), np.float64(0.5040946788442211), np.float64(0.6706051755765687), np.float64(0.48157241967279185)]

# %% [markdown]
# # View example predictions

# %%
net.eval()

# select random image from test set
image_name = random.choice(test_dataset.fnames)
image = cv2.imread(os.path.join(file_root_test, image_name))
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

print('predicting...')
result = predict_image(net, image_name, root_img_directory=file_root_test)
for left_up, right_bottom, class_name, _, prob in result:
    color = COLORS[VOC_CLASSES.index(class_name)]
    cv2.rectangle(image, left_up, right_bottom, color, 2)
    label = class_name + str(round(prob, 2))
    text_size, baseline = cv2.getTextSize(label, cv2.FONT_HERSHEY_SIMPLEX, 0.4, 1)
    p1 = (left_up[0], left_up[1] - text_size[1])
    cv2.rectangle(image, (p1[0] - 2 // 2, p1[1] - 2 - baseline), (p1[0] + text_size[0], p1[1] + text_size[1]),
                  color, -1)
    cv2.putText(image, label, (p1[0], p1[1] + baseline), cv2.FONT_HERSHEY_SIMPLEX, 0.4, (255, 255, 255), 1, 8)

plt.figure(figsize = (15,15))
plt.imshow(image)
# Out:
# predicting...

# %% [markdown]
# ## Evaluate on Test
#
# To evaluate detection results we use mAP (mean of average precision over each class)

# %%
test_aps = evaluate(net, test_dataset_file=annotation_file_test, img_root=file_root_test)
# Out:
# ---Evaluate model on test samples---
# 100%|██████████| 4950/4950 [01:46<00:00, 46.37it/s]
# ---class aeroplane ap 0.5593786946317048---
# ---class bicycle ap 0.650628463887343---
# ---class bird ap 0.496033109054446---
# ---class boat ap 0.3179856531886345---
# ---class bottle ap 0.18954884946621192---
# ---class bus ap 0.6528829141481661---
# ---class car ap 0.676926705559994---
# ---class cat ap 0.7177419557444841---
# ---class chair ap 0.3055840949062393---
# ---class cow ap 0.5072682008910645---
# ---class diningtable ap 0.40174977556694835---
# ---class dog ap 0.6877403517635892---
# ---class horse ap 0.6979427343799373---
# ---class motorbike ap 0.5907661504073733---
# ---class person ap 0.5263551555119249---
# ---class pottedplant ap 0.22896413328127588---
# ---class sheep ap 0.5784636761548603---
# ---class sofa ap 0.5040946788442211---
# ---class train ap 0.6706051755765687---
# ---class tvmonitor ap 0.48157241967279185---
# ---map 0.5221116446318891---

# %% [markdown]
# ### Cell added to get intermediate mAP values for students

# %%
network_paths = ['./checkpoints/detector_epoch_%d.pth' % epoch for epoch in [5, 10, 20, 30, 40]]+['./checkpoints/detector.pth']
for load_network_path in network_paths:
    print('Loading saved network from {}'.format(load_network_path))
    net_loaded =  resnet50().to(device)
    net_loaded.load_state_dict(torch.load(load_network_path))
    evaluate(net_loaded, test_dataset_file=annotation_file_test, img_root=file_root_test)
# Out:
# Loading saved network from ./checkpoints/detector_epoch_5.pth
# ---Evaluate model on test samples---
# 100%|██████████| 4950/4950 [01:43<00:00, 47.96it/s]
# ---class aeroplane ap 0.017543859649122806---
# ---class bicycle ap 0.10852847961393561---
# ---class bird ap 0.08220051889876803---
# ---class boat ap 0.0--- (no predictions for this class)
# ---class bottle ap 0.0---
# ---class bus ap 0.0--- (no predictions for this class)
# ---class car ap 0.2748205596944392---
# ---class cat ap 0.036312849162011177---
# ---class chair ap 0.053725573101828544---
# ---class cow ap 0.0--- (no predictions for this class)
# ---class diningtable ap 0.0--- (no predictions for this class)
# ---class dog ap 0.006134969325153374---
# ---class horse ap 0.008620689655172414---
# ---class motorbike ap 0.06699089152824927---
# ---class person ap 0.1932331212239436---
# ---class pottedplant ap 0.0068142361111111095---
# ---class sheep ap 0.0--- (no predictions for this class)
# ---class sofa ap 0.0--- (no predictions for this class)
# ---class train ap 0.0--- (no predictions for this class)
# ---class tvmonitor ap 0.08356279015225854---
# ---map 0.046924426905799684---
# Loading saved network from ./checkpoints/detector_epoch_10.pth
# ---Evaluate model on test samples---
# 100%|██████████| 4950/4950 [01:46<00:00, 46.56it/s]
# ---class aeroplane ap 0.35411796012173413---
# ---class bicycle ap 0.39307963882233826---
# ---class bird ap 0.2677707761894331---
# ---class boat ap 0.1005475782094498---
# ---class bottle ap 0.05044484984019342---
# ---class bus ap 0.3630602466222298---
# ---class car ap 0.5301233767248199---
# ---class cat ap 0.4191979409338873---
# ---class chair ap 0.17428603871156417---
# ---class cow ap 0.07992610553619862---
# ---class diningtable ap 0.05489194144699269---
# ---class dog ap 0.4626545299493753---
# ---class horse ap 0.41802043329759336---
# ---class motorbike ap 0.4185654841436606---
# ---class person ap 0.29537065390133577---
# ---class pottedplant ap 0.07788918128574804---
# ---class sheep ap 0.2934793582350497---
# ---class sofa ap 0.1220133221913244---
# ---class train ap 0.44924839018047824---
# ---class tvmonitor ap 0.30706242090883384---
# ---map 0.28158751136261206---
# Loading saved network from ./checkpoints/detector_epoch_20.pth
# ---Evaluate model on test samples---
# 100%|██████████| 4950/4950 [01:48<00:00, 45.77it/s]
# ---class aeroplane ap 0.38296633697812354---
# ---class bicycle ap 0.5283240445888646---
# ---class bird ap 0.4705833810595628---
# ---class boat ap 0.2676478966754249---
# ---class bottle ap 0.09571611147921116---
# ---class bus ap 0.6203447342972065---
# ---class car ap 0.6162099978232196---
# ---class cat ap 0.6266273115362475---
# ---class chair ap 0.2281609769738493---
# ---class cow ap 0.4895500287498401---
# ---class diningtable ap 0.2435306937079838---
# ---class dog ap 0.6102989373591645---
# ---class horse ap 0.6035055819192363---
# ---class motorbike ap 0.5301501576061074---
# ---class person ap 0.4713945087711452---
# ---class pottedplant ap 0.18257232393377887---
# ---class sheep ap 0.4708068077453246---
# ---class sofa ap 0.3765121107826001---
# ---class train ap 0.5966354187571683---
# ---class tvmonitor ap 0.41906834286343825---
# ---map 0.4415302851803748---
# Loading saved network from ./checkpoints/detector_epoch_30.pth
# ---Evaluate model on test samples---
# 100%|██████████| 4950/4950 [01:45<00:00, 46.94it/s]
# ---class aeroplane ap 0.5309568910204499---
# ---class bicycle ap 0.6209548449420444---
# ---class bird ap 0.45319403369518196---
# ---class boat ap 0.34069737358519303---
# ---class bottle ap 0.1616479849227658---
# ---class bus ap 0.5812653849388489---
# ---class car ap 0.6396693777585851---
# ---class cat ap 0.6919487038397067---
# ---class chair ap 0.28215275682448576---
# ---class cow ap 0.5901757167478827---
# ---class diningtable ap 0.37274979989196044---
# ---class dog ap 0.6598384740576124---
# ---class horse ap 0.6581230967996616---
# ---class motorbike ap 0.5165152032704055---
# ---class person ap 0.47079318612255155---
# ---class pottedplant ap 0.1981512942733908---
# ---class sheep ap 0.5560380272496244---
# ---class sofa ap 0.4927058210483677---
# ---class train ap 0.661974418953853---
# ---class tvmonitor ap 0.5126522680409806---
# ---map 0.49961023289917766---
# Loading saved network from ./checkpoints/detector_epoch_40.pth
# ---Evaluate model on test samples---
# 100%|██████████| 4950/4950 [01:43<00:00, 47.61it/s]
# ---class aeroplane ap 0.5836732075872195---
# ---class bicycle ap 0.6442084925089246---
# ---class bird ap 0.4997457894422038---
# ---class boat ap 0.2928314885457124---
# ---class bottle ap 0.1894833186223816---
# ---class bus ap 0.6479853278325192---
# ---class car ap 0.6709645372547628---
# ---class cat ap 0.7317285409635466---
# ---class chair ap 0.30836969996436414---
# ---class cow ap 0.5285599917121123---
# ---class diningtable ap 0.3795564499029953---
# ---class dog ap 0.6911662438788613---
# ---class horse ap 0.6889011339052978---
# ---class motorbike ap 0.5449916218571993---
# ---class person ap 0.5185354483817632---
# ---class pottedplant ap 0.21856252227737163---
# ---class sheep ap 0.5664383134737622---
# ---class sofa ap 0.5103669937171281---
# ---class train ap 0.6636990952045194---
# ---class tvmonitor ap 0.487200141190679---
# ---map 0.5183484179111661---
# Loading saved network from ./checkpoints/detector.pth
# ---Evaluate model on test samples---
# 100%|██████████| 4950/4950 [01:42<00:00, 48.10it/s]
# ---class aeroplane ap 0.5593786946317048---
# ---class bicycle ap 0.650628463887343---
# ---class bird ap 0.496033109054446---
# ---class boat ap 0.3179856531886345---
# ---class bottle ap 0.18954884946621192---
# ---class bus ap 0.6528829141481661---
# ---class car ap 0.676926705559994---
# ---class cat ap 0.7177419557444841---
# ---class chair ap 0.3055840949062393---
# ---class cow ap 0.5072682008910645---
# ---class diningtable ap 0.40174977556694835---
# ---class dog ap 0.6877403517635892---
# ---class horse ap 0.6979427343799373---
# ---class motorbike ap 0.5907661504073733---
# ---class person ap 0.5263551555119249---
# ---class pottedplant ap 0.22896413328127588---
# ---class sheep ap 0.5784636761548603---
# ---class sofa ap 0.5040946788442211---
# ---class train ap 0.6706051755765687---
# ---class tvmonitor ap 0.48157241967279185---
# ---map 0.5221116446318891---

# %%
output_submission_csv('my_solution.csv', test_aps)
