# %% [markdown]
# ### This file is to test whether the neural network is implemented correctly.

# %%
import matplotlib
print(matplotlib.__version__)
# Out:
# 3.10.1

# %%
# This is to test whether cuda version pytorch is ready(optional)
import torch
print("CUDA available:", torch.cuda.is_available())
print("CUDA version:", torch.version.cuda)

# Print the version of PyTorch
print("PyTorch version:", torch.__version__)
# Out:
# CUDA available: True
# CUDA version: 12.6
# PyTorch version: 2.6.0+cu126

# %%
import matplotlib.pyplot as plt
from models.neural_net_pytorch import NeuralNet

input_size = 2
hidden_sizes = [32, 32, 16]
output_size = 3
num_layers = 4
learning_rate = 0.01

net = NeuralNet(input_size, hidden_sizes, output_size, num_layers, learning_rate)

X = torch.randn((8, input_size))
y = torch.randn((8, output_size))

losses = []
for epoch in range(100):
    loss_val = net.backward_pass(X, y)
    losses.append(loss_val)

plt.plot(losses)
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Training Loss Curve")
plt.show()
